# %% [markdown]
# ## Carga el CSV de la carpeta de datos del tema llamado run.csv y responde a las siguientes preguntas.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("run.csv")

# %%
df
# Out:
#     Unnamed: 0  pulso.antes  pulso.despues hace.deporte fuma genero  altura  \
# 0            1           48             54           no   si      H   68.00
# 1            2           54             56           no   si      H   69.00
# 2            3           54             50           no   no      H   69.00
# 3            4           58             70           si   no      H   72.00
# 4            5           58             58           no   no      H   66.00
# 5            6           58             56           no   no      M   67.00
# 6            7           60             76           si   no      H   71.00
# 7            8           60             62           no   no      H   71.00
# 8            9           60             70           no   si      H   71.50
# 9           10           60             66           no   no      M   62.00
# 10          11           61             70           no   no      M   65.50
# ...

# %% [markdown]
# ### 1. Indica cuantos estudiantes formaron parte del estudio de deporte

# %%
df.shape
# Out:
# (92, 9)

# %% [markdown]
# ### R = 92 estudiantes

# %% [markdown]
# ### 2. Indica cuantos individuos son hombres y cuantos son mujeres

# %%
criterioH = df['genero'] == 'H'
criterioM = df['genero'] == 'M'

# %%
dfH = df[criterioH]
dfH.shape
# Out:
# (57, 9)

# %%
dfM = df[criterioM]
dfM.shape
# Out:
# (35, 9)

# %% [markdown]
# ### R = 57 hombres y 35 mujeres

# %% [markdown]
# ### 3. Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio y compara el valor de los que hacen ejercicio habitualmente y los que no. ¿Observas mucha diferencia?

# %%
criterio1 = df['hace.deporte'] == "no"
criterio2 = df['hace.deporte'] == "si"

# %%
dfsi = df[criterio2]
dfsi.var()
# Out:
# Unnamed: 0       743.702521
# pulso.antes      130.776471
# pulso.despues    358.845378
# altura            11.561660
# peso             512.033613
# dtype: float64

# %%
dfno = df[criterio1]
dfno.var()
# Out:
# Unnamed: 0       706.374687
# pulso.antes      116.998120
# pulso.despues     98.969925
# altura            13.603853
# peso             561.466792
# dtype: float64

# %% [markdown]
# ### R = Observo que los que no hacen deporte varían menos su pulso despues. Los que sí hacen deporte suben mucho más su ritmo.

# %% [markdown]
# ### 4. Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio  para los estudiantes que hacen ejercicio habitualmente y compara el valor de los hombres con el de las mujeres. ¿Observas mucha diferencia?

# %%
criterioH1 = dfsi['genero'] == 'H'
criterioM1 = dfsi['genero'] == 'M'

# %%
dfsiH = dfsi[criterioH1]
dfsiH.var()
# Out:
# Unnamed: 0       554.601449
# pulso.antes       79.065217
# pulso.despues    171.389493
# altura             6.173460
# peso             338.956522
# dtype: float64

# %%
dfsiM = dfsi[criterioM1]
dfsiM.var()
# Out:
# Unnamed: 0       814.963636
# pulso.antes      177.090909
# pulso.despues    164.563636
# altura             9.042045
# peso             153.418182
# dtype: float64

# %% [markdown]
# ### R = Se observa que el pulso de las mujeres antes es mayor que el de los hombres, sin embargo, el de las mujeres tiende a bajar muy poco y el de los hombres sube mucho.

# %% [markdown]
# ### 5. Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio para los estudiantes que no hacen ejercicio habitualmente y compara el valor de los fumadores con los no fumadores. ¿Observas mucha diferencia?

# %%
criterioF = df['fuma'] == 'si'
criterioNF = df['fuma'] == 'no'

# %%
dfSF = df[criterioF]
dfSF.var()
# Out:
# Unnamed: 0       897.962963
# pulso.antes      182.074074
# pulso.despues    236.966931
# altura            16.575645
# peso             523.841270
# dtype: float64

# %%
dfNF = df[criterioNF]
dfNF.var()
# Out:
# Unnamed: 0       634.825397
# pulso.antes       94.123016
# pulso.despues    319.618800
# altura            12.176696
# peso             557.014881
# dtype: float64

# %%
dfno.var()
# Out:
# Unnamed: 0       706.374687
# pulso.antes      116.998120
# pulso.despues     98.969925
# altura            13.603853
# peso             561.466792
# dtype: float64

# %% [markdown]
# ### R = Los estudiantes que no hacen ejercicio suelen reducir su pulso después de hacer ejercicio, los que no fuman comienzan con un pulso menor y suben considerablemente después de hacer ejercicio. Los estudiantes que fuman comienzan con un pulso mayor y sube bastante al terminar de hacer ejercicio.

# %% [markdown]
# ### 6. Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio de todos los estudiantes según el tipo de actividad física que realizan. ¿Observas alguna diferencia?

# %%
crit1 = df['tipo.actividad'] == 'nula'
crit2 = df['tipo.actividad'] == 'suave'
crit3 = df['tipo.actividad'] == 'moderada'
crit4 = df['tipo.actividad'] == 'intensa'

# %%
dfNul = df[crit1]
dfNul.var()
# Out:
# Unnamed: 0      NaN
# pulso.antes     NaN
# pulso.despues   NaN
# altura          NaN
# peso            NaN
# dtype: float64

# %%
dfSua = df[crit2]
dfSua.var()
# Out:
# Unnamed: 0       673.111111
# pulso.antes      109.777778
# pulso.despues     92.444444
# altura            20.111111
# peso             829.611111
# dtype: float64

# %%
dfMod =  df[crit3]
dfMod.var()
# Out:
# Unnamed: 0       701.328962
# pulso.antes      120.663388
# pulso.despues    364.670492
# altura            12.478381
# peso             589.121858
# dtype: float64

# %%
dfInt =  df[crit4]
dfInt.var()
# Out:
# Unnamed: 0       634.714286
# pulso.antes       92.657143
# pulso.despues     74.761905
# altura            14.232143
# peso             446.014286
# dtype: float64

# %% [markdown]
# ## Ejemplos de resolución

# %%
df.groupby("genero").count() #Número 2
# Out:
#         Unnamed: 0  pulso.antes  pulso.despues  hace.deporte  fuma  altura  \
# genero
# H               57           57             57            57    57      57
# M               35           35             35            35    35      35
#
#         peso  tipo.actividad
# genero
# H         57              57
# M         35              35

# %%
df['Var.pulso'] = (df['pulso.despues'] - df['pulso.antes'])  * 100 / df['pulso.despues']

df.groupby('hace.deporte').mean()

#Número 3
# Out:
#               Unnamed: 0  pulso.antes  pulso.despues     altura        peso  \
# hace.deporte
# no             47.017544    72.421053      72.315789  68.065789  141.122807
# si             45.657143    73.600000      92.514286  69.778571  151.714286
#
#               Var.pulso
# hace.deporte
# no            -0.150372
# si            18.715914

# %%
df[df['hace.deporte'] == "si"].groupby('genero').mean() #Número 4
# Out:
#         Unnamed: 0  pulso.antes  pulso.despues     altura        peso  \
# genero
# H        38.083333    70.250000      83.208333  71.229167  162.000000
# M        62.181818    80.909091     112.818182  66.613636  129.272727
#
#         Var.pulso
# genero
# H       14.371869
# M       28.193831

# %%
df[df['hace.deporte'] == "no"].groupby("fuma").mean() #Número 5
# Out:
#       Unnamed: 0  pulso.antes  pulso.despues     altura        peso  Var.pulso
# fuma
# no     45.512195    71.707317      71.512195  68.079268  138.195122  -0.319298
# si     50.875000    74.250000      74.375000  68.031250  148.625000   0.282501

# %%
df.groupby('tipo.actividad').mean() #Número 6
# Out:
#                 Unnamed: 0  pulso.antes  pulso.despues     altura        peso  \
# tipo.actividad
# intensa          43.285714    71.571429      72.190476  69.571429  147.285714
# moderada         45.934426    72.737705      82.786885  68.377049  143.754098
# nula              1.000000    48.000000      54.000000  68.000000  150.000000
# suave            62.888889    79.555556      82.222222  69.111111  149.111111
#
#                 Var.pulso
# tipo.actividad
# intensa          0.673985
# moderada         9.713154
# nula            11.111111
# suave            3.190957
